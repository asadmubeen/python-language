# %%
# arthimatic oprater +,-,* ,//,/,%
a = 70
b = 70
add= a+b
mul = a*b
div = a/b
flrdiv = a//b
mod = a%b
print(add,mul,div,flrdiv,mod)
# Out:
# 140 4900 1.0 1 0

# %%
# lgical oprater AND, OR, NOT
# OPRATER (AND) IS USE FOR (TRUE)
c = 10
d = 30
c>0 and d>0
# Out:
# True

# %%
#OPRATER (OR) I SUSE FOR (FALSE)
c<0 or d>0
# Out:
# True

# %%
#OPRATER (NOT) IS USE FOR (REVERSE)
print(not(c==9))
# Out:
# True

# %%
# Arthimatic assigment oprtaer
# =assigment oprtaer
# += 
# *=
# /=
# //=
# %=
add = 1
for i in range(1,11):
    add*=i
print(add)
# Out:
# 3628800
