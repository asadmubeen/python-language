# %%
# there is 5 data type 
# 1 string   2 inntager 3 double 4 boolean 5 flot 
# string  "khan"    
# intader -32000 to 32000
#double  milion of num 300000000 
# bolean  1 : 0
# flot 3.567 decmail value 
 
# we are starting practice on string 
# one mean thing in string we should use round bracket like this () 
a =("hello world")
print(a)
# Out:
# hello world

# %%
 
fname=("Asad")
lname=("Mubeen")
print(fname+lname)
# Out:
# AsadMubeen

# %%
# and if you want to store the paragraph the you should use thriple string in starte""" and in end """
string1=("""asalam alikum i am asad mubeen and  i belonging from pakhtoon family and i am also a student of AI 
dvdin the accedy of derajat it park it locatad on the main bunna road D I Khan """)
print(string1)
# Out:
# asalam alikum i am asad mubeen and  i belonging from pakhtoon family and i am also a student of AI
# dvdin the accedy of derajat it park it locatad on the main bunna road D I Khan

# %%
# IN this list2 we add some mathod 
# if you want to add some mathod then you have to close the sring in squre bracket[]
# The first one mathod is  (sort)
# and with the help of sort we can bring  evevry list in seqence 
string=["pakistan","afghnistan","amrica","africa"]
string.sort()
print(string)
# Out:
# ['afghnistan', 'africa', 'amrica', 'pakistan']

# %%
# now the seconde one is [apppend] mathod
# with the help of append we can add [NAME]our [NUMBER] in list
#  and it should  write in last
#  Now i want to add another name in string
string.append("melbone")
print(string)
# Out:
# ['afghnistan', 'africa', 'amrica', 'pakistan', 'melbone']

# %%
# AND now we can use delate mathod 
# with the help of delate mathod we can delate name and number in list from anywhwere 
# i want  to del the first name of string 
# when you want to delate some thing then yiu should be use only [del] tag 
del string[0]
print(string)
# Out:
# ['africa', 'amrica', 'pakistan', 'melbone']

# %%
# and the third one is upper mathod 
# if you writh the hole paragraph in small alfabat later and  you want to write in capitalalfabat
# then you shuld use the upper mathod
a="khanzada"
print(a.upper())
# Out:
# KHANZADA

# %%
# And also the lower is same like upper 
print(a.lower())
# Out:
# khanzada

# %%
#AND now we read slash n [\n]
# with the help of slash n we can start new line 
# like this 
print ("Asalam alikum \n my name i asad \n i read in class 9")
# Out:
# Asalam alikum
#  my name i asad
#  i read in class 9

# %%
# now we use the mathod of lenth
# in this mathod you well use () brackets and[] square bracket
Cd=["bmw","RR","bugati","civic"]

print(Cd)
# Out:
# ['bmw', 'RR', 'bugati', 'civic']

# %%
#Access the first element of list2
list2=["WAzir","masood","marwat","batani","gandapur"]
print(list2[0])
# Out:
# WAzir

# %%
# access the last element of list2
print(list2[-1])
# Out:
# gandapur

# %%
#SLICING
# IT IS posible to access a section of iteams from the list using the slicing opreter:not just a single ithem
print(list2[0:4])
# Out:
# ['WAzir', 'masood', 'marwat', 'batani']

# %%
arr=["khan","khanii","king","queen"]
print(arr)
# Out:
# ['khan', 'khanii', 'king', 'queen']

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 print(len.dc)()
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'dc'
