# %%
for khan in range(6):
     print("khan")
# Out:
# khan
# khan
# khan
# khan
# khan
# khan

# %%
AI =  "mobeen" #code
for name in range (3):
    print(AI)
# Out:
# mobeen
# mobeen
# mobeen

# %%
Ai = ["asad","wahib","khan","jamal"]
for fr in range  (4):
    print(Ai[0:3])
# Out:
# ['asad', 'wahib', 'khan']
# ['asad', 'wahib', 'khan']
# ['asad', 'wahib', 'khan']
# ['asad', 'wahib', 'khan']
