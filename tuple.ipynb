# %%
# To tupple  can not change 
# use only (index) , (len), 
a =(1,2,242,2,2,2,"asad",74,"khan",True)
print(a)
# Out:
# (1, 2, 242, 2, 2, 2, 'asad', 74, 'khan', True)

# %%
print(a[4])
# Out:
# 2

# %%
print(len(a))
# Out:
# 10

# %%
print(a.count(2))
# Out:
# 4

# %%
print(a.count("asad"))
# Out:
# 1
