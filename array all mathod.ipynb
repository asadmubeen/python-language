# %%
arr=[9,5,3,1,6,4,2,8,]
arr.append(13) # when we want to add number or name in arr then we use append mathod 
print(arr)
# Out:
# [9, 5, 3, 1, 6, 4, 2, 8, 13]

# %%
del arr[2] #when we want to delate num or nam efrom arr then we use del mathod
print(arr)
# Out:
# [9, 5, 1, 6, 4, 2, 8, 13]

# %%
remove_arr=[3] #when we want to remove number or name from array then we use remove mathod 
print(f"the remove num from arr is;{remove_arr}")
# Out:
# the remove num from arr is;[3]

# %%
arr.insert(4,17); #insert mathod then we use when you want to add some thing on main point 
print(arr)
# Out:
# [9, 5, 1, 6, 17, 4, 2, 8, 13]

# %%
arr.pop() # when we use pop mathod then the last word well remove  without any index
print(arr)
# Out:
# [9, 5, 1, 6, 17, 4, 2, 8]

# %%
print(arr[4])  # with the help of index you should print one word or one name
# Out:
# 17

# %%
print(arr[0:5])
# Out:
# [9, 5, 1, 6, 17]

# %%
arr.sort() # with the help of sort mathod we should bring array in order  
print(arr)
# Out:
# [1, 2, 4, 5, 6, 8, 9, 17]
